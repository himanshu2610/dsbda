# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df1 = df.copy()

# %%
df1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df1['Age'].fillna(df['Age'].mean())
# Out:
# 0      25.000000
# 1      25.000000
# 2      27.000000
# 3      22.000000
# 4      29.000000
#          ...
# 453    26.000000
# 454    24.000000
# 455    26.000000
# 456    26.000000
# 457    26.938731
# Name: Age, Length: 458, dtype: float64

# %%
df1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
age = df1['Age'].fillna(df['Age'].mean(),inplace = True)

# %%
df1
# Out:
#               Name            Team  Number Position        Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.000000    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.000000    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.000000    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.000000    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.000000   6-10   231.0
# ..             ...             ...     ...      ...        ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.000000    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.000000    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.000000    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.000000    7-0   231.0
# 457            NaN             NaN     NaN      NaN  26.938731    NaN     NaN
#
# ...

# %%
df1['Age'] = df1['Age'].astype(int)

# %%
df1
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C   26    7-0   231.0
# 457            NaN             NaN     NaN      NaN   26    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df['Age'].min()
# Out:
# 19.0

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df.count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
df.Age.max()
# Out:
# 40.0

# %% [raw]
# groupheight = df.groupBy(df.Height)
# groupheight

# %%
groupheight = df.groupby(df.Height)
groupheight

# %%
groupheight.get_group('6-2')
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 0        Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2
# 8         Terry Rozier          Boston Celtics    12.0       PG  22.0    6-2
# 36   Langston Galloway         New York Knicks     2.0       SG  24.0    6-2
# 54      T.J. McConnell      Philadelphia 76ers    12.0       PG  24.0    6-2
# 131       Ronnie Price            Phoenix Suns    14.0       PG  32.0    6-2
# 144         Seth Curry        Sacramento Kings    30.0       SG  25.0    6-2
# 210          Joe Young          Indiana Pacers     1.0       PG  23.0    6-2
# 256        Jason Terry         Houston Rockets    31.0       SG  38.0    6-2
# 264      Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 279        Norris Cole    New Orleans Pelicans    30.0       PG  27.0    6-2
# 283      Toney Douglas    New Orleans Pelicans    16.0       PG  30.0    6-2
# ...

# %%
groupheight.get_group('5-11')
# Out:
#              Name            Team  Number Position   Age Height  Weight  \
# 22   Shane Larkin   Brooklyn Nets     0.0       PG  23.0   5-11   175.0
# 130  Phil Pressey    Phoenix Suns    25.0       PG  25.0   5-11   175.0
# 203     Ty Lawson  Indiana Pacers    10.0       PG  28.0   5-11   195.0
#
#             College     Salary
# 22       Miami (FL)  1500000.0
# 130        Missouri    55722.0
# 203  North Carolina   211744.0

# %%
groupheight.get_group('6-7')
# Out:
#                         Name                    Team  Number Position   Age  \
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 32    Thanasis Antetokounmpo         New York Knicks    43.0       SF  23.0
# 43             Sasha Vujacic         New York Knicks    18.0       SG  32.0
# 64             DeMar DeRozan         Toronto Raptors    10.0       SG  26.0
# 71             Terrence Ross         Toronto Raptors    31.0       SF  25.0
# 82            Draymond Green   Golden State Warriors    23.0       PF  26.0
# 84          Shaun Livingston   Golden State Warriors    34.0       PG  30.0
# 89             Klay Thompson   Golden State Warriors    11.0       SG  26.0
# 97            Wesley Johnson    Los Angeles Clippers    33.0       SF  28.0
# ...

# %%
df.Age.value_counts()
# Out:
# 24.0    47
# 25.0    45
# 27.0    41
# 23.0    41
# 26.0    36
# 28.0    31
# 30.0    31
# 29.0    28
# 22.0    26
# 31.0    22
# 20.0    19
# 21.0    19
# 33.0    14
# 32.0    13
# 34.0    10
# 36.0    10
# 35.0     9
# 37.0     4
# 38.0     4
# 40.0     3
# 39.0     2
# 19.0     2
# Name: Age, dtype: int64

# %%
bins = [19,25,31,36,40]
labels = ['19-24','25-30','31-35','36-40']
df['AgeGroup'] = pd.cut(df['Age'],bins = bins , labels = labels,right = False)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary AgeGroup
# 0                Texas  7730337.0    25-30
# ...

# %%
df.groupby('AgeGroup')['Salary'].mean()
# Out:
# AgeGroup
# 19-24    2.706212e+06
# 25-30    5.895838e+06
# 31-35    6.662026e+06
# 36-40    3.847918e+06
# Name: Salary, dtype: float64

# %%
df.groupby('Height')['Salary'].mean()
# Out:
# Height
# 5-11    5.891553e+05
# 5-9     6.912869e+06
# 6-0     5.784075e+06
# 6-1     5.217919e+06
# 6-10    5.200605e+06
# 6-11    6.544397e+06
# 6-2     3.335362e+06
# 6-3     5.884952e+06
# 6-4     4.646163e+06
# 6-5     4.377241e+06
# 6-6     3.556182e+06
# 6-7     3.473986e+06
# 6-8     5.950412e+06
# 6-9     4.133756e+06
# 7-0     5.287712e+06
# 7-1     7.400988e+06
# 7-2     6.835639e+06
# 7-3     2.307930e+06
# Name: Salary, dtype: float64

# %%
df.AgeGroup.value_counts()
# Out:
# 25-30    212
# 19-24    154
# 31-35     68
# 36-40     20
# Name: AgeGroup, dtype: int64

# %%
groupheight.Salary.mean()
# Out:
# Height
# 5-11    5.891553e+05
# 5-9     6.912869e+06
# 6-0     5.784075e+06
# 6-1     5.217919e+06
# 6-10    5.200605e+06
# 6-11    6.544397e+06
# 6-2     3.335362e+06
# 6-3     5.884952e+06
# 6-4     4.646163e+06
# 6-5     4.377241e+06
# 6-6     3.556182e+06
# 6-7     3.473986e+06
# 6-8     5.950412e+06
# 6-9     4.133756e+06
# 7-0     5.287712e+06
# 7-1     7.400988e+06
# 7-2     6.835639e+06
# 7-3     2.307930e+06
# Name: Salary, dtype: float64

# %%
groupAge = df.groupby(df['AgeGroup'])

# %%
groupAge.get_group('36-40')
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 46         Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 72          Luis Scola         Toronto Raptors     4.0       PF  36.0    6-9
# 93      Jamal Crawford    Los Angeles Clippers    11.0       SG  36.0    6-5
# 101        Paul Pierce    Los Angeles Clippers    34.0       SF  38.0    6-7
# 102     Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# 109        Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 119  Metta World Peace      Los Angeles Lakers    37.0       SF  36.0    6-7
# 139       Caron Butler        Sacramento Kings    31.0       SF  36.0    6-7
# 183        Steve Blake         Detroit Pistons    22.0       PG  36.0    6-3
# 236      Dirk Nowitzki        Dallas Mavericks    41.0       PF  37.0    7-0
# 256        Jason Terry         Houston Rockets    31.0       SG  38.0    6-2
# ...

# %%
df.AgeGroup.value_counts()
# Out:
# 25-30    212
# 19-24    154
# 31-35     68
# 36-40     20
# Name: AgeGroup, dtype: int64

# %%
df.groupby('AgeGroup').get_group('36-40')['Salary'].mean()
# Out:
# 3847917.8421052634

# %%
salaryList = list(df.groupby(df.AgeGroup))

# %%
salaryList
# Out:
# [('19-24',
#                   Name            Team  Number Position   Age Height  Weight  \
#   3        R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#   6      Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#   8       Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
#   9       Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#   10   Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
#   ..               ...             ...     ...      ...   ...    ...     ...
#   446   Derrick Favors       Utah Jazz    15.0       PF  24.0   6-10   265.0
#   447      Rudy Gobert       Utah Jazz    27.0        C  23.0    7-1   245.0
#   449      Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
#   452       Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
#   454        Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
#
# ...

# %%
df.Age.max()
# Out:
# 40.0
